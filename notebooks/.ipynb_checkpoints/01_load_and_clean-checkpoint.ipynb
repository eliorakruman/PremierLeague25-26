# %%
import pandas as pd

DATA_PATH = "../data/raw/E0.csv"

df_raw = pd.read_csv(DATA_PATH, parse_dates=["Date"],
    dayfirst=True)
df_raw.head()
# Out:
#   Div       Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0 2025-08-15  20:00    Liverpool  Bournemouth     4     2   H     1     0
# 1  E0 2025-08-16  12:30  Aston Villa    Newcastle     0     0   D     0     0
# 2  E0 2025-08-16  15:00     Brighton       Fulham     1     1   D     0     0
# 3  E0 2025-08-16  15:00   Sunderland     West Ham     3     0   H     0     0
# 4  E0 2025-08-16  15:00    Tottenham      Burnley     3     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94     1.76
# 1  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95     1.74
# 2  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80     1.96
# 3  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86     1.78
# 4  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88     1.83
#
#    BFECAHH  BFECAHA
# 0     2.14     1.86
# ...

# %%
cols = ["Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR"]

df = df_raw[cols].copy()
df.head()
# Out:
#         Date     HomeTeam     AwayTeam  FTHG  FTAG FTR
# 0 2025-08-15    Liverpool  Bournemouth     4     2   H
# 1 2025-08-16  Aston Villa    Newcastle     0     0   D
# 2 2025-08-16     Brighton       Fulham     1     1   D
# 3 2025-08-16   Sunderland     West Ham     3     0   H
# 4 2025-08-16    Tottenham      Burnley     3     0   H

# %%
df = df.rename(columns={
    "Date":"date",
    "HomeTeam":"home_team",
    "AwayTeam":"away_team",
    "FTHG":"home_goals",
    "FTAG":"away_goals",
    "FTR":"result"
})

df.head()
# Out:
#         date    home_team    away_team  home_goals  away_goals result
# 0 2025-08-15    Liverpool  Bournemouth           4           2      H
# 1 2025-08-16  Aston Villa    Newcastle           0           0      D
# 2 2025-08-16     Brighton       Fulham           1           1      D
# 3 2025-08-16   Sunderland     West Ham           3           0      H
# 4 2025-08-16    Tottenham      Burnley           3           0      H

# %%
df["season"]="2024/25"

df.head()
# Out:
#         date    home_team    away_team  home_goals  away_goals result   season
# 0 2025-08-15    Liverpool  Bournemouth           4           2      H  2024/25
# 1 2025-08-16  Aston Villa    Newcastle           0           0      D  2024/25
# 2 2025-08-16     Brighton       Fulham           1           1      D  2024/25
# 3 2025-08-16   Sunderland     West Ham           3           0      H  2024/25
# 4 2025-08-16    Tottenham      Burnley           3           0      H  2024/25

# %%
df["home_points"] = df["result"].apply(lambda x:3 if x=="H" else 1 if x=="D" else 0)
df["away_points"] = df["result"].apply(lambda x:3 if x=="A" else 1 if x=="D" else 0)

df.head()
# Out:
#         date    home_team    away_team  home_goals  away_goals result  \
# 0 2025-08-15    Liverpool  Bournemouth           4           2      H
# 1 2025-08-16  Aston Villa    Newcastle           0           0      D
# 2 2025-08-16     Brighton       Fulham           1           1      D
# 3 2025-08-16   Sunderland     West Ham           3           0      H
# 4 2025-08-16    Tottenham      Burnley           3           0      H
#
#     season  home_points  away_points
# 0  2024/25            3            0
# 1  2024/25            1            1
# 2  2024/25            1            1
# 3  2024/25            3            0
# 4  2024/25            3            0

# %%
df["home_goal_diff"] = df["home_goals"] - df["away_goals"]
df["away_goal_diff"] = df["away_goals"] - df["home_goals"]

df.head()
# Out:
#         date    home_team    away_team  home_goals  away_goals result  \
# 0 2025-08-15    Liverpool  Bournemouth           4           2      H
# 1 2025-08-16  Aston Villa    Newcastle           0           0      D
# 2 2025-08-16     Brighton       Fulham           1           1      D
# 3 2025-08-16   Sunderland     West Ham           3           0      H
# 4 2025-08-16    Tottenham      Burnley           3           0      H
#
#     season  home_points  away_points  home_goal_diff  away_goal_diff
# 0  2024/25            3            0               2              -2
# 1  2024/25            1            1               0               0
# 2  2024/25            1            1               0               0
# 3  2024/25            3            0               3              -3
# 4  2024/25            3            0               3              -3

# %%
teams = pd.concat([df["home_team"],df["away_team"]]).unique()
teams
# Out:
# array(['Liverpool', 'Aston Villa', 'Brighton', 'Sunderland', 'Tottenham',
#        'Wolves', 'Chelsea', "Nott'm Forest", 'Man United', 'Leeds',
#        'West Ham', 'Man City', 'Bournemouth', 'Brentford', 'Burnley',
#        'Arsenal', 'Crystal Palace', 'Everton', 'Fulham', 'Newcastle'],
#       dtype=object)

# %%
home_stats = df.groupby("home_team").agg(
played_home=("home_team","count"),
home_wins=("home_points", lambda x: (x==3).sum()),
home_losses=("home_points", lambda x: (x==0).sum()),
home_draws=("home_points", lambda x: (x==1).sum()),
goals_for_home=("home_goals","sum"),
goals_against_home=("away_goals","sum"),
points_home=("home_points","sum")
).reset_index().rename(columns={"home_team":"team"})

away_stats = df.groupby("away_team").agg(
played_away=("away_team","count"),
away_wins=("away_points", lambda x: (x==3).sum()),
away_losses=("away_points", lambda x: (x==0).sum()),
away_draws=("away_points", lambda x: (x==1).sum()),
goals_for_away=("away_goals","sum"),
goals_against_away=("home_goals","sum"),
points_away=("away_points","sum")
).reset_index().rename(columns={"away_team":"team"})

# %%
league_table = pd.merge(home_stats,away_stats,on="team")

league_table["played"]=league_table["played_home"]+league_table["played_away"]
league_table["wins"]=league_table["home_wins"]+league_table["away_wins"]
league_table["losses"]=league_table["home_losses"]+league_table["away_losses"]
league_table["draws"]=league_table["home_draws"]+league_table["away_draws"]
league_table["goals_scored"]=league_table["goals_for_home"]+league_table["goals_for_away"]
league_table["goals_conceded"]=league_table["goals_against_home"]+league_table["goals_against_away"]
league_table["goal_difference"]=league_table["goals_scored"]+league_table["goals_conceded"]
league_table["points"]=league_table["points_home"]+league_table["points_away"]

league_table = league_table[["team","played","wins","losses","draws","goals_scored","goals_conceded","goal_difference","points"]]

league_table.head()
# Out:
#           team  played  wins  losses  draws  goals_scored  goals_conceded  \
# 0      Arsenal      18    13       2      3            33              11
# 1  Aston Villa      18    12       3      3            29              19
# 2  Bournemouth      18     5       6      7            27              33
# 3    Brentford      18     8       8      2            28              26
# 4     Brighton      18     6       6      6            26              25
#
#    goal_difference  points
# 0               44      42
# 1               48      39
# 2               60      22
# 3               54      26
# 4               51      24

# %%
league_table = league_table.sort_values(
by=["points","goal_difference","goals_scored"],ascending=False
).reset_index(drop=True)

league_table["position"]=league_table.index + 1

league_table = league_table[["position"] + [c for c in league_table.columns if c != "position"]]

league_table.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6b55">
#   <thead>
#     <tr>
#       <th id="T_f6b55_level0_col0" class="col_heading level0 col0" >position</th>
#       <th id="T_f6b55_level0_col1" class="col_heading level0 col1" >team</th>
#       <th id="T_f6b55_level0_col2" class="col_heading level0 col2" >played</th>
#       <th id="T_f6b55_level0_col3" class="col_heading level0 col3" >wins</th>
#       <th id="T_f6b55_level0_col4" class="col_heading level0 col4" >losses</th>
#       <th id="T_f6b55_level0_col5" class="col_heading level0 col5" >draws</th>
#       <th id="T_f6b55_level0_col6" class="col_heading level0 col6" >goals_scored</th>
#       <th id="T_f6b55_level0_col7" class="col_heading level0 col7" >goals_conceded</th>
#       <th id="T_f6b55_level0_col8" class="col_heading level0 col8" >goal_difference</th>
#       <th id="T_f6b55_level0_col9" class="col_heading level0 col9" >points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
home_matches=df[["date","home_team","home_goals","away_goals","home_points"]].copy().rename(columns={"home_team":"team","home_points":"points"})
home_matches["home_away"]="H"

away_matches=df[["date","away_team","away_goals","home_goals","away_points"]].copy().rename(columns={"away_team":"team","away_points":"points"})
away_matches["home_away"]="A"

team_matches = pd.concat([home_matches,away_matches],ignore_index=True)

team_matches = team_matches.sort_values("date").reset_index(drop=True)

team_matches.head()
# Out:
#         date         team  home_goals  away_goals  points home_away
# 0 2025-08-15    Liverpool           4           2       3         H
# 1 2025-08-15  Bournemouth           4           2       0         A
# 2 2025-08-16      Burnley           3           0       0         A
# 3 2025-08-16     West Ham           3           0       0         A
# 4 2025-08-16       Fulham           1           1       1         A

# %%
def result_label(points):
    if points==3:
        return "🟢"
    if points==1:
        return "⚪️"
    else:
        return "🔴"
    
team_matches["result"]=team_matches["points"].apply(result_label)

team_matches.head()
# Out:
#         date         team  home_goals  away_goals  points home_away result
# 0 2025-08-15    Liverpool           4           2       3         H      🟢
# 1 2025-08-15  Bournemouth           4           2       0         A      🔴
# 2 2025-08-16      Burnley           3           0       0         A      🔴
# 3 2025-08-16     West Ham           3           0       0         A      🔴
# 4 2025-08-16       Fulham           1           1       1         A     ⚪️

# %%
recent_form = team_matches.groupby("team").tail(5).groupby("team")["result"].apply(lambda x: "".join(x))
recent_form
# Out:
# team
# Arsenal              🟢🔴🟢🟢🟢
# Aston Villa          🟢🟢🟢🟢🟢
# Bournemouth       🔴⚪️⚪️⚪️🔴
# Brentford           🔴🔴⚪️🟢🟢
# Brighton           🔴⚪️🔴⚪️🔴
# Burnley            🔴🔴🔴⚪️⚪️
# Chelsea            🔴⚪️🟢⚪️🔴
# Crystal Palace       🟢🟢🔴🔴🔴
# Everton             🟢🟢🔴🔴⚪️
# Fulham               🔴🔴🟢🟢🟢
# Leeds             🟢⚪️⚪️🟢⚪️
# Liverpool          ⚪️⚪️🟢🟢🟢
# Man City             🟢🟢🟢🟢🟢
# Man United         ⚪️🟢⚪️🔴🟢
# Newcastle          ⚪️🟢🔴⚪️🔴
# Nott'm Forest        🟢🔴🟢🔴🔴
# Sunderland        ⚪️🔴🟢⚪️⚪️
# Tottenham           ⚪️🟢🔴🔴🟢
# West Ham           ⚪️⚪️🔴🔴🔴
# Wolves               🔴🔴🔴🔴🔴
# Name: result, dtype: object

# %%
league_table = league_table.merge(recent_form,on="team",how="left").rename(columns={"result":"form"})
league_table
# Out:
#     position            team  played  wins  losses  draws  goals_scored  \
# 0          1         Arsenal      18    13       2      3            33
# 1          2        Man City      18    13       4      1            43
# 2          3     Aston Villa      18    12       3      3            29
# 3          4       Liverpool      18    10       6      2            30
# 4          5      Man United      18     8       5      5            32
# 5          6         Chelsea      18     8       5      5            30
# 6          7      Sunderland      18     7       4      7            20
# 7          8       Brentford      18     8       8      2            28
# 8          9          Fulham      18     8       8      2            25
# 9         10  Crystal Palace      18     7       6      5            21
# 10        11       Tottenham      18     7       7      4            27
# 11        12         Everton      18     7       7      4            18
# ...

# %%
def highlight_position(row):
    pos = row.position
    if pos<=4:
        return ["background-color: lightgreen"] * len(row)
    if pos<=6:
        return ["background-color: khaki"] * len(row)
    if pos>=18:
        return ["background-color: lightcoral"] * len(row)
    else:
        return [""] * len(row)
    
styled_table = league_table.style.apply(highlight_position,axis=1).hide(axis="index")
styled_table
# Out:
# <style type="text/css">
# #T_2bdb3_row0_col0, #T_2bdb3_row0_col1, #T_2bdb3_row0_col2, #T_2bdb3_row0_col3, #T_2bdb3_row0_col4, #T_2bdb3_row0_col5, #T_2bdb3_row0_col6, #T_2bdb3_row0_col7, #T_2bdb3_row0_col8, #T_2bdb3_row0_col9, #T_2bdb3_row0_col10, #T_2bdb3_row1_col0, #T_2bdb3_row1_col1, #T_2bdb3_row1_col2, #T_2bdb3_row1_col3, #T_2bdb3_row1_col4, #T_2bdb3_row1_col5, #T_2bdb3_row1_col6, #T_2bdb3_row1_col7, #T_2bdb3_row1_col8, #T_2bdb3_row1_col9, #T_2bdb3_row1_col10, #T_2bdb3_row2_col0, #T_2bdb3_row2_col1, #T_2bdb3_row2_col2, #T_2bdb3_row2_col3, #T_2bdb3_row2_col4, #T_2bdb3_row2_col5, #T_2bdb3_row2_col6, #T_2bdb3_row2_col7, #T_2bdb3_row2_col8, #T_2bdb3_row2_col9, #T_2bdb3_row2_col10, #T_2bdb3_row3_col0, #T_2bdb3_row3_col1, #T_2bdb3_row3_col2, #T_2bdb3_row3_col3, #T_2bdb3_row3_col4, #T_2bdb3_row3_col5, #T_2bdb3_row3_col6, #T_2bdb3_row3_col7, #T_2bdb3_row3_col8, #T_2bdb3_row3_col9, #T_2bdb3_row3_col10 {
#   background-color: lightgreen;
# }
# ...

# %%
league_table.to_csv("../data/processed/league_table.csv", index=False)

# %%
home_stats["venue"]="home"
away_stats["venue"]="away"

home_stats = home_stats.rename(columns={
    "played_home": "played",
    "home_wins": "wins",
    "home_losses": "losses",
    "home_draws": "draws",
    "goals_for_home": "goals_for",
    "goals_against_home": "goals_against",
    "points_home": "points"
})

away_stats = away_stats.rename(columns={
    "played_away": "played",
    "away_wins": "wins",
    "away_losses": "losses",
    "away_draws": "draws",
    "goals_for_away": "goals_for",
    "goals_against_away": "goals_against",
    "points_away": "points"
})

home_away_stats = pd.concat([home_stats, away_stats], ignore_index=True)

home_away_stats.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea4bd">
#   <thead>
#     <tr>
#       <th id="T_ea4bd_level0_col0" class="col_heading level0 col0" >team</th>
#       <th id="T_ea4bd_level0_col1" class="col_heading level0 col1" >played</th>
#       <th id="T_ea4bd_level0_col2" class="col_heading level0 col2" >wins</th>
#       <th id="T_ea4bd_level0_col3" class="col_heading level0 col3" >losses</th>
#       <th id="T_ea4bd_level0_col4" class="col_heading level0 col4" >draws</th>
#       <th id="T_ea4bd_level0_col5" class="col_heading level0 col5" >goals_for</th>
#       <th id="T_ea4bd_level0_col6" class="col_heading level0 col6" >goals_against</th>
#       <th id="T_ea4bd_level0_col7" class="col_heading level0 col7" >points</th>
#       <th id="T_ea4bd_level0_col8" class="col_heading level0 col8" >venue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea4bd_row0_col0" class="data row0 col0" >Arsenal</td>
# ...

# %%
home_away_stats.to_csv("../data/processed/home_away_stats.csv", index=False)
